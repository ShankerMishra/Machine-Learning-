# %%
import pandas as pd

# %%
weather=pd.read_csv("E:\\datasets\\weather.csv")

# %%
weather
# Out:
#            date  maximum temperature  minimum temperature  \
# 0    01-01-2016                 42.0                   34
# 1    02-01-2016                 40.0                   32
# 2    03-01-2016                 45.0                   35
# 3    04-01-2016                 36.0                   14
# 4    05-01-2016                 29.0                   11
# 5    06-01-2016                 41.0                   25
# 6    07-01-2016                 46.0                   31
# 7    08-01-2016                 46.0                   31
# 8    09-01-2016                  NaN                   40
# 9    10-01-2016                 59.0                   40
# 10   11-01-2016                 40.0                   26
# 11   12-01-2016                 44.0                   25
# 12   13-01-2016                 30.0                   22
# 13   14-01-2016                 38.0                   22
# 14   15-01-2016                 51.0                   34
# ...

# %%
weather=weather.fillna(method="ffill")

# %%
x=weather.iloc[:10,0]

# %%
y=weather.iloc[:10,1]

# %%
x
# Out:
# 0    01-01-2016
# 1    02-01-2016
# 2    03-01-2016
# 3    04-01-2016
# 4    05-01-2016
# 5    06-01-2016
# 6    07-01-2016
# 7    08-01-2016
# 8    09-01-2016
# 9    10-01-2016
# Name: date, dtype: object

# %%
y
# Out:
# 0    42.0
# 1    40.0
# 2    45.0
# 3    36.0
# 4    29.0
# 5    41.0
# 6    46.0
# 7    46.0
# 8    46.0
# 9    59.0
# Name: maximum temperature, dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(x,y)

# %%
plt.scatter(x,y)

# %%
plt.scatter(x,y,marker="*",c="green")

# %%
x=weather.iloc[:10,0]

# %%
x=x.str.rstrip("2016")

# %%
x
# Out:
# 0    01-01-
# 1    02-01-
# 2    03-01-
# 3    04-01-
# 4    05-01-
# 5    06-01-
# 6    07-01-
# 7    08-01-
# 8    09-01-
# 9    10-01-
# Name: date, dtype: object

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(x,y)

# %%
plt.scatter(x,y,marker="*",c="green")

# %%
plt.hist(y)
# Out:
# (array([1., 0., 1., 1., 2., 4., 0., 0., 0., 1.]),
#  array([29., 32., 35., 38., 41., 44., 47., 50., 53., 56., 59.]),
#  <a list of 10 Patch objects>)

# %%
plt.bar(x,y)
# Out:
# <BarContainer object of 10 artists>

# %%
import seaborn as sdm

# %%
tips=sdm.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 13        18.43  3.00    Male     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# ...

# %%
sdm.countplot(x='sex',data=tips)

# %%
sdm.pairplot(tips)#type of plotting where fron dataset all the numeric values will be fetched and plotted

# %%
sdm.boxplot(x='day',y='total_bill',data=tips)
