# %%
import pandas as pd

# %%
salary=pd.read_csv("D:\\datasets\\salary_data.csv")

# %%
salary
# Out:
#     YearsExperience  Salary
# 0               1.1   39343
# 1               1.3   46205
# 2               1.5   37731
# 3               2.0   43525
# 4               2.2   39891
# 5               2.9   56642
# 6               3.0   60150
# 7               3.2   54445
# 8               3.2   64445
# 9               3.7   57189
# 10              3.9   63218
# 11              4.0   55794
# 12              4.0   56957
# 13              4.1   57081
# 14              4.5   61111
# 15              4.9   67938
# 16              5.1   66029
# 17              5.3   83088
# 18              5.9   81363
# 19              6.0   93940
# 20              6.8   91738
# 21              7.1   98273
# 22              7.9  101302
# 23              8.2  113812
# 24              8.7  109431
# 25              9.0  105582
# 26              9.5  116969
# 27              9.6  112635
# 28             10.3  122391
# 29             10.5  121872

# %%
x=salary.iloc[:,0:1]

# %%
x
# Out:
#     YearsExperience
# 0               1.1
# 1               1.3
# 2               1.5
# 3               2.0
# 4               2.2
# 5               2.9
# 6               3.0
# 7               3.2
# 8               3.2
# 9               3.7
# 10              3.9
# 11              4.0
# 12              4.0
# 13              4.1
# 14              4.5
# 15              4.9
# 16              5.1
# 17              5.3
# 18              5.9
# 19              6.0
# 20              6.8
# 21              7.1
# 22              7.9
# 23              8.2
# 24              8.7
# 25              9.0
# 26              9.5
# 27              9.6
# 28             10.3
# 29             10.5

# %%
y=salary.iloc[:,[1]]

# %%
y
# Out:
#     Salary
# 0    39343
# 1    46205
# 2    37731
# 3    43525
# 4    39891
# 5    56642
# 6    60150
# 7    54445
# 8    64445
# 9    57189
# 10   63218
# 11   55794
# 12   56957
# 13   57081
# 14   61111
# 15   67938
# 16   66029
# 17   83088
# 18   81363
# 19   93940
# 20   91738
# 21   98273
# 22  101302
# 23  113812
# 24  109431
# 25  105582
# 26  116969
# 27  112635
# 28  122391
# 29  121872

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.10,random_state=48)

# %%
salary.isnull().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
from sklearn.linear_model import LinearRegression
reg=LinearRegression()
reg.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
reg.coef_
# Out:
# array([[9402.88958312]])

# %%
reg.intercept_
# Out:
# array([26037.87700728])

# %%
y_pred=reg.predict(x_test)

# %%
y_p=reg.predict([[9]])

# %%
y_p
# Out:
# array([[110663.88325538]])

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.9983936416509868

# %%
'''ts_score=[]
import numpy as np
for j in range(100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=j,test_size=0.1)
    lr= LinearRegression().fit(x_train,y_train)
    
    ts_score.append(lr.score(x_test,y_test))
K = ts_score.index(np.max(ts_score))'''

# %%
#K
# Out:
# 48

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x_test,y_test,color='red')
plt.plot(x_test,y_pred,color='blue')
plt.title("revenue vs reviews (test set)")
plt.xlabel('customer review')
plt.ylabel('revenue generated')
# Out:
# Text(0, 0.5, 'revenue generated')

# %%
housing=pd.read_csv("D:\\datasets\\Housing.csv")

# %%
housing
# Out:
#         price  lotsize  bedrooms  bathrms  stories driveway recroom fullbase  \
# 0     42000.0     5850         3        1        2      yes      no      yes
# 1     38500.0     4000         2        1        1      yes      no       no
# 2     49500.0     3060         3        1        1      yes      no       no
# 3     60500.0     6650         3        1        2      yes     yes       no
# 4     61000.0     6360         2        1        1      yes      no       no
# 5     66000.0     4160         3        1        1      yes     yes      yes
# 6     66000.0     3880         3        2        2      yes      no      yes
# 7     69000.0     4160         3        1        3      yes      no       no
# 8     83800.0     4800         3        1        1      yes     yes      yes
# 9     88500.0     5500         3        2        4      yes     yes       no
# 10    90000.0     7200         3        2        1      yes      no      yes
# ...

# %%
import numpy as np

# %%
c=housing.corr()

# %%
c
# Out:
#              price   lotsize  bedrooms   bathrms   stories  garagepl
# price     1.000000  0.535796  0.366447  0.516719  0.421190  0.383302
# lotsize   0.535796  1.000000  0.151851  0.193833  0.083675  0.352872
# bedrooms  0.366447  0.151851  1.000000  0.373769  0.407974  0.139117
# bathrms   0.516719  0.193833  0.373769  1.000000  0.324066  0.178178
# stories   0.421190  0.083675  0.407974  0.324066  1.000000  0.043412
# garagepl  0.383302  0.352872  0.139117  0.178178  0.043412  1.000000

# %%
import seaborn as sns

# %%
sns.heatmap(c)

# %%
sns.pairplot(housing.iloc[:,[-1,0]])

# %%
x =housing.iloc[:,[1,2,3,4,10]]
y= housing.iloc[:,0]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.1,random_state=76)

# %%
from sklearn.linear_model import LinearRegression
reg=LinearRegression()
reg.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
reg.coef_
# Out:
# array([4.57610130e+00, 2.62766943e+03, 1.62148174e+04, 7.69671358e+03,
#        5.46344998e+03])

# %%
reg.intercept_
# Out:
# -1586.6045125834498

# %%
y_pred=reg.predict(x_test)

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.7202745396736385

# %%
'''ts_score=[]
import numpy as np
for j in range(100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=j,test_size=0.1)
    lr= LinearRegression().fit(x_train,y_train)
    
    ts_score.append(lr.score(x_test,y_test))
K = ts_score.index(np.max(ts_score))'''

# %%
#K
# Out:
# 76

# %%
import matplotlib.pyplot as plt 
plt.scatter(y_pred,x_test.iloc[:,-1],color='black')
plt.scatter(y_test,x_test.iloc[:,-1],color='green')
