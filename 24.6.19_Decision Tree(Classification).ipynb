# %%
#Nodes will be x and leafs will be y 
#If everything is yes or everythin No then entropy is zero
#If 50-50 then entropy will be 1. (entropy=maximum amount of infomation gain.amount of randomness)
#pick root node with higesht information gain.

# %% [markdown]
# import numpy as np
# import pandas as pd
# from sklearn.model_selection import train_test_split
# from sklear.tree import DecisionTreeClassifier
# from sklearn.metrics import accuracy_score
# from sklear.metrics import confusion_matrix,classification

# %%
import numpy as np 
import pandas as pd 
from sklearn.model_selection import train_test_split 

from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score 
from sklearn.metrics import confusion_matrix,classification

# %%
balance_data=pd.read_csv("D:\\datasets\\BalanceScale.csv",names=['class','rb','lb','rw','lw'])

# %%
balance_data
# Out:
#     class  rb  lb  rw  lw
# 0       B   1   1   1   1
# 1       R   1   1   1   2
# 2       R   1   1   1   3
# 3       R   1   1   1   4
# 4       R   1   1   1   5
# 5       R   1   1   2   1
# 6       R   1   1   2   2
# 7       R   1   1   2   3
# 8       R   1   1   2   4
# 9       R   1   1   2   5
# 10      R   1   1   3   1
# 11      R   1   1   3   2
# 12      R   1   1   3   3
# 13      R   1   1   3   4
# 14      R   1   1   3   5
# 15      R   1   1   4   1
# 16      R   1   1   4   2
# 17      R   1   1   4   3
# 18      R   1   1   4   4
# 19      R   1   1   4   5
# 20      R   1   1   5   1
# 21      R   1   1   5   2
# 22      R   1   1   5   3
# 23      R   1   1   5   4
# 24      R   1   1   5   5
# 25      L   1   2   1   1
# 26      B   1   2   1   2
# 27      R   1   2   1   3
# 28      R   1   2   1   4
# 29      R   1   2   1   5
# ..    ...  ..  ..  ..  ..
# 595     L   5   4   5   1
# 596     L   5   4   5   2
# 597     L   5   4   5   3
# ...

# %%
x=balance_data.values[:,1:]
y=balance_data.values[:,0]

# %%
x
# Out:
# array([[1, 1, 1, 1],
#        [1, 1, 1, 2],
#        [1, 1, 1, 3],
#        ...,
#        [5, 5, 5, 3],
#        [5, 5, 5, 4],
#        [5, 5, 5, 5]], dtype=object)

# %%
y
# Out:
# array(['B', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R',
#        'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'L',
#        'B', 'R', 'R', 'R', 'B', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R',
#        'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'L', 'L',
#        'B', 'R', 'R', 'L', 'R', 'R', 'R', 'R', 'B', 'R', 'R', 'R', 'R',
#        'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'L', 'L', 'L',
#        'B', 'R', 'L', 'B', 'R', 'R', 'R', 'L', 'R', 'R', 'R', 'R', 'B',
#        'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'L', 'L', 'L', 'L',
#        'B', 'L', 'L', 'R', 'R', 'R', 'L', 'R', 'R', 'R', 'R', 'L', 'R',
#        'R', 'R', 'R', 'B', 'R', 'R', 'R', 'R', 'L', 'B', 'R', 'R', 'R',
#        'B', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R',
#        'R', 'R', 'R', 'R', 'R', 'R', 'R', 'L', 'L', 'L', 'B', 'R', 'L',
#        'B', 'R', 'R', 'R', 'L', 'R', 'R', 'R', 'R', 'B', 'R', 'R', 'R',
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.15,random_state=81)

# %%
balance_data.isnull().sum()
# Out:
# class    0
# rb       0
# lb       0
# rw       0
# lw       0
# dtype: int64

# %%
'''ts_score=[]
import numpy as np
for j in range(100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=j,test_size=0.15)
    lr= DecisionTreeClassifier().fit(x_train,y_train)
    
    ts_score.append(lr.score(x_test,y_test))
K = ts_score.index(np.max(ts_score))

# %%
#K
# Out:
# 81

# %%
#decision tree
clf_entropy=DecisionTreeClassifier(criterion="entropy",min_samples_split=.2)
clf_entropy.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=0.2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
y_pred_en = clf_entropy.predict(x_test)

# %%
accuracy_score(y_test,y_pred_en)
# Out:
# 0.7446808510638298
