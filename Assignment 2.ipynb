# %%
import pandas as pd

# %%
loan=pd.read_csv("D:\\datasets\\loan_pred.csv")

# %%
loan
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# 5    LP001011    Male     Yes          2      Graduate           Yes
# 6    LP001013    Male     Yes          0  Not Graduate            No
# 7    LP001014    Male     Yes         3+      Graduate            No
# 8    LP001018    Male     Yes          2      Graduate            No
# 9    LP001020    Male     Yes          1      Graduate            No
# 10   LP001024    Male     Yes          2      Graduate            No
# 11   LP001027    Male     Yes          2      Graduate           NaN
# 12   LP001028    Male     Yes          2      Graduate            No
# ...

# %%
loan.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
loan.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
loan.fillna(loan['LoanAmount'].mean(),inplace=True)

# %%
loan
# Out:
#       Loan_ID   Gender Married Dependents     Education Self_Employed  \
# 0    LP001002     Male      No          0      Graduate            No
# 1    LP001003     Male     Yes          1      Graduate            No
# 2    LP001005     Male     Yes          0      Graduate           Yes
# 3    LP001006     Male     Yes          0  Not Graduate            No
# 4    LP001008     Male      No          0      Graduate            No
# 5    LP001011     Male     Yes          2      Graduate           Yes
# 6    LP001013     Male     Yes          0  Not Graduate            No
# 7    LP001014     Male     Yes         3+      Graduate            No
# 8    LP001018     Male     Yes          2      Graduate            No
# 9    LP001020     Male     Yes          1      Graduate            No
# 10   LP001024     Male     Yes          2      Graduate            No
# 11   LP001027     Male     Yes          2      Graduate       146.412
# ...

# %%
loan['Credit_History']=loan.fillna(method="bfill")

# %%
loan.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term     14
# Credit_History        0
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
y=loan.iloc[:,8]

# %%
plt.hist(y)#Q(6)
# Out:
# (array([ 72., 332., 143.,  33.,  15.,   6.,   5.,   3.,   3.,   2.]),
#  array([  9. ,  78.1, 147.2, 216.3, 285.4, 354.5, 423.6, 492.7, 561.8,
#         630.9, 700. ]),
#  <a list of 10 Patch objects>)

# %%
loan
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# 5    LP001011    Male     Yes          2      Graduate           Yes
# 6    LP001013    Male     Yes          0  Not Graduate            No
# 7    LP001014    Male     Yes         3+      Graduate            No
# 8    LP001018    Male     Yes          2      Graduate            No
# 9    LP001020    Male     Yes          1      Graduate            No
# 10   LP001024    Male     Yes          2      Graduate            No
# 11   LP001027    Male     Yes          2      Graduate           NaN
# 12   LP001028    Male     Yes          2      Graduate            No
# ...

# %%
import seaborn as sns

# %%
sns.boxplot(y='ApplicantIncome',data=loan)

# %%
x=pd.get_dummies(loan['Gender'])

# %%
x
# Out:
#      Female  Male
# 0         0     1
# 1         0     1
# 2         0     1
# 3         0     1
# 4         0     1
# 5         0     1
# 6         0     1
# 7         0     1
# 8         0     1
# 9         0     1
# 10        0     1
# 11        0     1
# 12        0     1
# 13        0     1
# 14        0     1
# 15        0     1
# 16        0     1
# 17        1     0
# 18        0     1
# 19        0     1
# 20        0     1
# 21        0     1
# 22        0     1
# 23        0     0
# 24        0     1
# 25        0     1
# 26        0     1
# 27        0     1
# 28        0     1
# 29        1     0
# ..      ...   ...
# 584       0     1
# 585       0     1
# 586       0     1
# 587       1     0
# 588       0     0
# 589       0     1
# 590       0     1
# 591       0     1
# 592       0     0
# 593       0     1
# 594       0     1
# 595       0     1
# 596       0     1
# 597       0     1
# 598       0     1
# 599       0     1
# 600       1     0
# 601       0     1
# ...

# %%
loan=loan.drop(['Gender'],axis=1)

# %%
loan=pd.concat([loan,x],axis=1)

# %%
loan
# Out:
#       Loan_ID Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0    LP001002      No          0      Graduate            No             5849
# 1    LP001003     Yes          1      Graduate            No             4583
# 2    LP001005     Yes          0      Graduate           Yes             3000
# 3    LP001006     Yes          0  Not Graduate            No             2583
# 4    LP001008      No          0      Graduate            No             6000
# 5    LP001011     Yes          2      Graduate           Yes             5417
# 6    LP001013     Yes          0  Not Graduate            No             2333
# 7    LP001014     Yes         3+      Graduate            No             3036
# 8    LP001018     Yes          2      Graduate            No             4006
# 9    LP001020     Yes          1      Graduate            No            12841
# 10   LP001024     Yes          2      Graduate            No             3200
# ...

# %%
y1=loan.iloc[:10,-7]

# %%
x1=loan.iloc[:10,-1]

# %%
plt.bar(x1,y1)
# Out:
# <BarContainer object of 10 artists>

# %%
x2=loan.iloc[:10,-2]

# %%
plt.bar(x2,y1)
# Out:
# <BarContainer object of 10 artists>
